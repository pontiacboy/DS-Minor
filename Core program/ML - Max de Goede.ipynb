# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import time
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from utils import mnist_reader

# %% [markdown]
# # 1) Loading test and training dataset
# Splitting data set into test/train dataset.

# %%
X_train, y_train = mnist_reader.load_mnist('data/fashion', kind='train')
X_test, y_test = mnist_reader.load_mnist('data/fashion', kind='t10k')

# %%
X_test2 = X_test
X_train2 = X_train
y_test2 = y_test
y_train2 = y_train

# %%
y_train[5685]
# Out:
# 6

# %%
image = X_train[5685,:].reshape((28,28))
plt.imshow(image)

# %% [markdown]
# # 2) Train a Random Forest Classifier and time that it takes to train the algorithm.

# %%
rfc = RandomForestClassifier()

start = time.time()
rfc.fit(X_train, y_train)
end = time.time()
rfc_timer = end-start
print('Time spent on RFC standard --',end-start)
predict = rfc.predict(X_test)
print('Prediction --', predict)
# Out:
# C:\Users\Max\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Time spent on RFC standard -- 18.87619376182556
# Prediction -- [9 2 1 ... 8 1 7]

# %%
start = time.time()
predict = rfc.predict(X_test)
end = time.time()
print('Time spent after Prediction PCA  --',end-start)
# Out:
# Time spent after Prediction PCA  -- 0.10736274719238281

# %%
rfc.score(X_train,y_train)
print ("Train Standard RFC --", rfc.score(X_train,y_train))
# Out:
# Train Standard RFC -- 0.99585

# %%
test_resultrfc = rfc.score(X_test,y_test)
print ("Test Standard RFC --", rfc.score(X_test,y_test))
# Out:
# Test Standard RFC -- 0.855

# %%
acc = metrics.accuracy_score(predict,y_test)
print("Test accuracy_score --",acc)
# Out:
# Test accuracy_score -- 0.855

# %%
dft = pd.DataFrame()
dft['pred'] = predict
dft['Actual'] = y_test
        
dft.iloc[:,0]
count = 0
for index, row in dft.iterrows():
    if dft.iloc[index,0] != dft.iloc[index,1]:
        print('Index number of change--',index,' /Pred--', dft.iloc[index,0],'/ Actual--',dft.iloc[index,1])
        count = count + 1
# Out:
# Index number of change-- 12  /Pred-- 5 / Actual-- 7
# Index number of change-- 17  /Pred-- 3 / Actual-- 4
# Index number of change-- 21  /Pred-- 7 / Actual-- 5
# Index number of change-- 23  /Pred-- 5 / Actual-- 9
# Index number of change-- 25  /Pred-- 2 / Actual-- 4
# Index number of change-- 27  /Pred-- 3 / Actual-- 0
# Index number of change-- 29  /Pred-- 4 / Actual-- 3
# Index number of change-- 40  /Pred-- 0 / Actual-- 6
# Index number of change-- 42  /Pred-- 6 / Actual-- 3
# Index number of change-- 43  /Pred-- 9 / Actual-- 7
# Index number of change-- 48  /Pred-- 4 / Actual-- 2
# Index number of change-- 51  /Pred-- 2 / Actual-- 4
# Index number of change-- 66  /Pred-- 0 / Actual-- 2
# Index number of change-- 67  /Pred-- 4 / Actual-- 3
# Index number of change-- 68  /Pred-- 7 / Actual-- 9
# Index number of change-- 72  /Pred-- 8 / Actual-- 2
# Index number of change-- 89  /Pred-- 2 / Actual-- 6
# Index number of change-- 98  /Pred-- 2 / Actual-- 4
# Index number of change-- 122  /Pred-- 7 / Actual-- 9
# Index number of change-- 127  /Pred-- 2 / Actual-- 4
# Index number of change-- 147  /Pred-- 3 / Actual-- 6
# Index number of change-- 150  /Pred-- 3 / Actual-- 4
# Index number of change-- 151  /Pred-- 2 / Actual-- 4
# Index number of change-- 153  /Pred-- 3 / Actual-- 4
# Index number of change-- 155  /Pred-- 6 / Actual-- 0
# Index number of change-- 166  /Pred-- 2 / Actual-- 4
# Index number of change-- 183  /Pred-- 0 / Actual-- 6
# Index number of change-- 222  /Pred-- 6 / Actual-- 2
# Index number of change-- 227  /Pred-- 6 / Actual-- 2
# Index number of change-- 239  /Pred-- 2 / Actual-- 4
# Index number of change-- 241  /Pred-- 4 / Actual-- 6
# Index number of change-- 244  /Pred-- 2 / Actual-- 6
# Index number of change-- 247  /Pred-- 2 / Actual-- 4
# Index number of change-- 249  /Pred-- 4 / Actual-- 2
# Index number of change-- 252  /Pred-- 4 / Actual-- 6
# Index number of change-- 271  /Pred-- 6 / Actual-- 3
# Index number of change-- 282  /Pred-- 2 / Actual-- 6
# Index number of change-- 285  /Pred-- 4 / Actual-- 6
# Index number of change-- 316  /Pred-- 7 / Actual-- 9
# Index number of change-- 320  /Pred-- 6 / Actual-- 8
# Index number of change-- 324  /Pred-- 6 / Actual-- 4
# Index number of change-- 325  /Pred-- 2 / Actual-- 6
# Index number of change-- 332  /Pred-- 6 / Actual-- 0
# Index number of change-- 344  /Pred-- 0 / Actual-- 6
# Index number of change-- 378  /Pred-- 3 / Actual-- 4
# Index number of change-- 381  /Pred-- 6 / Actual-- 0
# Index number of change-- 382  /Pred-- 0 / Actual-- 2
# Index number of change-- 389  /Pred-- 2 / Actual-- 6
# Index number of change-- 396  /Pred-- 6 / Actual-- 4
# Index number of change-- 404  /Pred-- 3 / Actual-- 4
# Index number of change-- 406  /Pred-- 2 / Actual-- 6
# Index number of change-- 409  /Pred-- 3 / Actual-- 1
# Index number of change-- 410  /Pred-- 3 / Actual-- 0
# Index number of change-- 413  /Pred-- 6 / Actual-- 2
# Index number of change-- 418  /Pred-- 7 / Actual-- 5
# Index number of change-- 419  /Pred-- 2 / Actual-- 4
# Index number of change-- 441  /Pred-- 7 / Actual-- 9
# Index number of change-- 443  /Pred-- 0 / Actual-- 8
# Index number of change-- 444  /Pred-- 4 / Actual-- 6
# Index number of change-- 454  /Pred-- 2 / Actual-- 0
# Index number of change-- 457  /Pred-- 4 / Actual-- 2
# Index number of change-- 460  /Pred-- 0 / Actual-- 3
# Index number of change-- 474  /Pred-- 0 / Actual-- 6
# Index number of change-- 480  /Pred-- 7 / Actual-- 5
# Index number of change-- 490  /Pred-- 6 / Actual-- 3
# Index number of change-- 499  /Pred-- 3 / Actual-- 0
# Index number of change-- 503  /Pred-- 9 / Actual-- 7
# Index number of change-- 526  /Pred-- 2 / Actual-- 4
# Index number of change-- 542  /Pred-- 7 / Actual-- 5
# Index number of change-- 548  /Pred-- 4 / Actual-- 6
# Index number of change-- 560  /Pred-- 1 / Actual-- 3
# Index number of change-- 562  /Pred-- 2 / Actual-- 6
# Index number of change-- 563  /Pred-- 0 / Actual-- 6
# Index number of change-- 565  /Pred-- 0 / Actual-- 6
# Index number of change-- 569  /Pred-- 0 / Actual-- 3
# Index number of change-- 578  /Pred-- 0 / Actual-- 3
# Index number of change-- 581  /Pred-- 0 / Actual-- 6
# Index number of change-- 595  /Pred-- 2 / Actual-- 6
# Index number of change-- 607  /Pred-- 6 / Actual-- 3
# Index number of change-- 612  /Pred-- 0 / Actual-- 6
# Index number of change-- 621  /Pred-- 4 / Actual-- 2
# Index number of change-- 622  /Pred-- 0 / Actual-- 6
# Index number of change-- 623  /Pred-- 7 / Actual-- 9
# Index number of change-- 632  /Pred-- 6 / Actual-- 2
# Index number of change-- 634  /Pred-- 4 / Actual-- 6
# Index number of change-- 635  /Pred-- 4 / Actual-- 8
# Index number of change-- 639  /Pred-- 2 / Actual-- 4
# Index number of change-- 663  /Pred-- 3 / Actual-- 1
# Index number of change-- 664  /Pred-- 2 / Actual-- 6
# Index number of change-- 665  /Pred-- 2 / Actual-- 4
# Index number of change-- 669  /Pred-- 6 / Actual-- 8
# Index number of change-- 670  /Pred-- 6 / Actual-- 2
# Index number of change-- 671  /Pred-- 5 / Actual-- 7
# Index number of change-- 681  /Pred-- 6 / Actual-- 0
# Index number of change-- 688  /Pred-- 6 / Actual-- 3
# Index number of change-- 697  /Pred-- 6 / Actual-- 8
# Index number of change-- 702  /Pred-- 2 / Actual-- 4
# Index number of change-- 705  /Pred-- 9 / Actual-- 7
# Index number of change-- 711  /Pred-- 3 / Actual-- 6
# Index number of change-- 719  /Pred-- 5 / Actual-- 0
# Index number of change-- 722  /Pred-- 7 / Actual-- 5
# Index number of change-- 725  /Pred-- 4 / Actual-- 6
# Index number of change-- 732  /Pred-- 0 / Actual-- 2
# Index number of change-- 735  /Pred-- 7 / Actual-- 5
# Index number of change-- 753  /Pred-- 0 / Actual-- 3
# Index number of change-- 760  /Pred-- 0 / Actual-- 2
# Index number of change-- 761  /Pred-- 2 / Actual-- 6
# Index number of change-- 764  /Pred-- 6 / Actual-- 0
# Index number of change-- 785  /Pred-- 7 / Actual-- 5
# Index number of change-- 787  /Pred-- 3 / Actual-- 1
# Index number of change-- 788  /Pred-- 9 / Actual-- 7
# Index number of change-- 800  /Pred-- 9 / Actual-- 7
# Index number of change-- 801  /Pred-- 2 / Actual-- 4
# Index number of change-- 805  /Pred-- 2 / Actual-- 4
# Index number of change-- 815  /Pred-- 2 / Actual-- 4
# Index number of change-- 830  /Pred-- 6 / Actual-- 4
# Index number of change-- 841  /Pred-- 4 / Actual-- 2
# Index number of change-- 851  /Pred-- 4 / Actual-- 2
# Index number of change-- 856  /Pred-- 0 / Actual-- 8
# Index number of change-- 860  /Pred-- 2 / Actual-- 6
# Index number of change-- 877  /Pred-- 2 / Actual-- 4
# Index number of change-- 881  /Pred-- 6 / Actual-- 0
# Index number of change-- 890  /Pred-- 3 / Actual-- 0
# Index number of change-- 894  /Pred-- 3 / Actual-- 0
# Index number of change-- 898  /Pred-- 7 / Actual-- 5
# Index number of change-- 899  /Pred-- 9 / Actual-- 7
# Index number of change-- 902  /Pred-- 7 / Actual-- 5
# Index number of change-- 905  /Pred-- 6 / Actual-- 4
# Index number of change-- 907  /Pred-- 6 / Actual-- 4
# Index number of change-- 909  /Pred-- 2 / Actual-- 6
# Index number of change-- 921  /Pred-- 4 / Actual-- 6
# Index number of change-- 933  /Pred-- 2 / Actual-- 4
# Index number of change-- 937  /Pred-- 6 / Actual-- 0
# Index number of change-- 938  /Pred-- 2 / Actual-- 6
# Index number of change-- 956  /Pred-- 2 / Actual-- 6
# Index number of change-- 965  /Pred-- 6 / Actual-- 0
# Index number of change-- 966  /Pred-- 0 / Actual-- 6
# Index number of change-- 968  /Pred-- 0 / Actual-- 6
# Index number of change-- 971  /Pred-- 0 / Actual-- 6
# Index number of change-- 976  /Pred-- 6 / Actual-- 2
# Index number of change-- 977  /Pred-- 0 / Actual-- 6
# Index number of change-- 978  /Pred-- 7 / Actual-- 5
# Index number of change-- 979  /Pred-- 0 / Actual-- 3
# Index number of change-- 985  /Pred-- 6 / Actual-- 0
# Index number of change-- 993  /Pred-- 7 / Actual-- 5
# Index number of change-- 994  /Pred-- 2 / Actual-- 4
# Index number of change-- 1000  /Pred-- 6 / Actual-- 0
# Index number of change-- 1004  /Pred-- 2 / Actual-- 6
# Index number of change-- 1005  /Pred-- 4 / Actual-- 0
# Index number of change-- 1008  /Pred-- 0 / Actual-- 6
# Index number of change-- 1025  /Pred-- 4 / Actual-- 6
# Index number of change-- 1026  /Pred-- 6 / Actual-- 4
# Index number of change-- 1029  /Pred-- 1 / Actual-- 3
# Index number of change-- 1046  /Pred-- 4 / Actual-- 6
# Index number of change-- 1050  /Pred-- 2 / Actual-- 4
# Index number of change-- 1054  /Pred-- 7 / Actual-- 9
# Index number of change-- 1056  /Pred-- 0 / Actual-- 6
# Index number of change-- 1058  /Pred-- 2 / Actual-- 6
# Index number of change-- 1065  /Pred-- 2 / Actual-- 4
# Index number of change-- 1074  /Pred-- 6 / Actual-- 4
# Index number of change-- 1091  /Pred-- 6 / Actual-- 1
# Index number of change-- 1094  /Pred-- 6 / Actual-- 8
# Index number of change-- 1096  /Pred-- 8 / Actual-- 6
# Index number of change-- 1101  /Pred-- 6 / Actual-- 4
# Index number of change-- 1104  /Pred-- 6 / Actual-- 4
# Index number of change-- 1107  /Pred-- 2 / Actual-- 6
# Index number of change-- 1110  /Pred-- 0 / Actual-- 5
# Index number of change-- 1111  /Pred-- 3 / Actual-- 0
# Index number of change-- 1121  /Pred-- 2 / Actual-- 6
# Index number of change-- 1124  /Pred-- 2 / Actual-- 0
# Index number of change-- 1125  /Pred-- 2 / Actual-- 4
# Index number of change-- 1129  /Pred-- 0 / Actual-- 6
# Index number of change-- 1131  /Pred-- 4 / Actual-- 6
# Index number of change-- 1139  /Pred-- 6 / Actual-- 0
# Index number of change-- 1160  /Pred-- 3 / Actual-- 4
# Index number of change-- 1162  /Pred-- 4 / Actual-- 6
# Index number of change-- 1164  /Pred-- 9 / Actual-- 7
# Index number of change-- 1165  /Pred-- 2 / Actual-- 6
# Index number of change-- 1174  /Pred-- 4 / Actual-- 6
# Index number of change-- 1177  /Pred-- 0 / Actual-- 6
# Index number of change-- 1185  /Pred-- 6 / Actual-- 4
# Index number of change-- 1188  /Pred-- 0 / Actual-- 6
# Index number of change-- 1192  /Pred-- 6 / Actual-- 2
# Index number of change-- 1197  /Pred-- 4 / Actual-- 6
# Index number of change-- 1213  /Pred-- 4 / Actual-- 2
# Index number of change-- 1226  /Pred-- 2 / Actual-- 4
# Index number of change-- 1231  /Pred-- 6 / Actual-- 0
# Index number of change-- 1235  /Pred-- 0 / Actual-- 6
# Index number of change-- 1236  /Pred-- 0 / Actual-- 6
# Index number of change-- 1249  /Pred-- 6 / Actual-- 0
# Index number of change-- 1251  /Pred-- 3 / Actual-- 4
# Index number of change-- 1254  /Pred-- 3 / Actual-- 2
# Index number of change-- 1256  /Pred-- 2 / Actual-- 8
# Index number of change-- 1262  /Pred-- 1 / Actual-- 4
# Index number of change-- 1285  /Pred-- 6 / Actual-- 0
# Index number of change-- 1286  /Pred-- 6 / Actual-- 8
# Index number of change-- 1288  /Pred-- 9 / Actual-- 7
# Index number of change-- 1294  /Pred-- 0 / Actual-- 6
# Index number of change-- 1297  /Pred-- 2 / Actual-- 4
# Index number of change-- 1300  /Pred-- 5 / Actual-- 8
# Index number of change-- 1305  /Pred-- 6 / Actual-- 0
# Index number of change-- 1315  /Pred-- 4 / Actual-- 2
# Index number of change-- 1326  /Pred-- 6 / Actual-- 3
# Index number of change-- 1329  /Pred-- 2 / Actual-- 4
# Index number of change-- 1334  /Pred-- 0 / Actual-- 4
# Index number of change-- 1336  /Pred-- 6 / Actual-- 3
# Index number of change-- 1339  /Pred-- 3 / Actual-- 2
# Index number of change-- 1374  /Pred-- 4 / Actual-- 2
# Index number of change-- 1388  /Pred-- 0 / Actual-- 4
# Index number of change-- 1399  /Pred-- 3 / Actual-- 0
# Index number of change-- 1408  /Pred-- 6 / Actual-- 4
# Index number of change-- 1425  /Pred-- 6 / Actual-- 2
# Index number of change-- 1431  /Pred-- 4 / Actual-- 2
# Index number of change-- 1449  /Pred-- 4 / Actual-- 2
# Index number of change-- 1455  /Pred-- 4 / Actual-- 8
# Index number of change-- 1458  /Pred-- 0 / Actual-- 6
# Index number of change-- 1462  /Pred-- 8 / Actual-- 4
# Index number of change-- 1471  /Pred-- 7 / Actual-- 9
# Index number of change-- 1485  /Pred-- 3 / Actual-- 1
# Index number of change-- 1487  /Pred-- 0 / Actual-- 6
# Index number of change-- 1495  /Pred-- 6 / Actual-- 0
# Index number of change-- 1496  /Pred-- 2 / Actual-- 6
# Index number of change-- 1501  /Pred-- 7 / Actual-- 5
# Index number of change-- 1502  /Pred-- 4 / Actual-- 6
# Index number of change-- 1504  /Pred-- 3 / Actual-- 0
# Index number of change-- 1509  /Pred-- 0 / Actual-- 2
# Index number of change-- 1515  /Pred-- 2 / Actual-- 6
# Index number of change-- 1522  /Pred-- 7 / Actual-- 9
# Index number of change-- 1524  /Pred-- 1 / Actual-- 3
# Index number of change-- 1527  /Pred-- 6 / Actual-- 2
# Index number of change-- 1544  /Pred-- 5 / Actual-- 9
# Index number of change-- 1559  /Pred-- 0 / Actual-- 6
# Index number of change-- 1567  /Pred-- 5 / Actual-- 7
# Index number of change-- 1572  /Pred-- 6 / Actual-- 0
# Index number of change-- 1575  /Pred-- 6 / Actual-- 2
# Index number of change-- 1583  /Pred-- 5 / Actual-- 7
# Index number of change-- 1593  /Pred-- 2 / Actual-- 4
# Index number of change-- 1620  /Pred-- 0 / Actual-- 6
# Index number of change-- 1632  /Pred-- 5 / Actual-- 9
# Index number of change-- 1642  /Pred-- 8 / Actual-- 6
# Index number of change-- 1644  /Pred-- 2 / Actual-- 4
# Index number of change-- 1645  /Pred-- 8 / Actual-- 6
# Index number of change-- 1650  /Pred-- 0 / Actual-- 6
# Index number of change-- 1655  /Pred-- 4 / Actual-- 2
# Index number of change-- 1659  /Pred-- 3 / Actual-- 1
# Index number of change-- 1701  /Pred-- 2 / Actual-- 6
# Index number of change-- 1706  /Pred-- 0 / Actual-- 6
# Index number of change-- 1708  /Pred-- 2 / Actual-- 6
# Index number of change-- 1712  /Pred-- 0 / Actual-- 6
# Index number of change-- 1718  /Pred-- 5 / Actual-- 9
# Index number of change-- 1725  /Pred-- 0 / Actual-- 6
# Index number of change-- 1726  /Pred-- 4 / Actual-- 2
# Index number of change-- 1731  /Pred-- 6 / Actual-- 0
# Index number of change-- 1732  /Pred-- 4 / Actual-- 2
# Index number of change-- 1743  /Pred-- 4 / Actual-- 2
# Index number of change-- 1744  /Pred-- 2 / Actual-- 6
# Index number of change-- 1745  /Pred-- 2 / Actual-- 6
# Index number of change-- 1754  /Pred-- 0 / Actual-- 6
# Index number of change-- 1756  /Pred-- 0 / Actual-- 6
# Index number of change-- 1759  /Pred-- 2 / Actual-- 4
# Index number of change-- 1771  /Pred-- 0 / Actual-- 6
# Index number of change-- 1777  /Pred-- 6 / Actual-- 0
# Index number of change-- 1798  /Pred-- 9 / Actual-- 7
# Index number of change-- 1811  /Pred-- 2 / Actual-- 4
# Index number of change-- 1816  /Pred-- 9 / Actual-- 7
# Index number of change-- 1817  /Pred-- 7 / Actual-- 9
# Index number of change-- 1825  /Pred-- 7 / Actual-- 5
# Index number of change-- 1836  /Pred-- 6 / Actual-- 0
# Index number of change-- 1837  /Pred-- 4 / Actual-- 2
# Index number of change-- 1851  /Pred-- 4 / Actual-- 2
# Index number of change-- 1852  /Pred-- 8 / Actual-- 3
# Index number of change-- 1855  /Pred-- 2 / Actual-- 4
# Index number of change-- 1866  /Pred-- 9 / Actual-- 7
# Index number of change-- 1879  /Pred-- 2 / Actual-- 4
# Index number of change-- 1895  /Pred-- 2 / Actual-- 4
# Index number of change-- 1907  /Pred-- 5 / Actual-- 9
# Index number of change-- 1917  /Pred-- 2 / Actual-- 4
# Index number of change-- 1922  /Pred-- 2 / Actual-- 6
# Index number of change-- 1928  /Pred-- 4 / Actual-- 2
# Index number of change-- 1943  /Pred-- 0 / Actual-- 6
# Index number of change-- 1944  /Pred-- 2 / Actual-- 6
# Index number of change-- 1945  /Pred-- 3 / Actual-- 0
# Index number of change-- 1953  /Pred-- 7 / Actual-- 5
# Index number of change-- 1955  /Pred-- 3 / Actual-- 1
# Index number of change-- 1957  /Pred-- 4 / Actual-- 2
# Index number of change-- 1968  /Pred-- 0 / Actual-- 3
# Index number of change-- 1970  /Pred-- 6 / Actual-- 0
# Index number of change-- 1980  /Pred-- 6 / Actual-- 8
# Index number of change-- 1998  /Pred-- 4 / Actual-- 6
# Index number of change-- 2001  /Pred-- 3 / Actual-- 2
# Index number of change-- 2010  /Pred-- 4 / Actual-- 6
# Index number of change-- 2016  /Pred-- 2 / Actual-- 6
# Index number of change-- 2020  /Pred-- 4 / Actual-- 2
# Index number of change-- 2022  /Pred-- 9 / Actual-- 7
# Index number of change-- 2037  /Pred-- 7 / Actual-- 5
# Index number of change-- 2039  /Pred-- 3 / Actual-- 2
# Index number of change-- 2042  /Pred-- 2 / Actual-- 4
# Index number of change-- 2048  /Pred-- 5 / Actual-- 7
# Index number of change-- 2049  /Pred-- 2 / Actual-- 6
# Index number of change-- 2062  /Pred-- 3 / Actual-- 4
# Index number of change-- 2069  /Pred-- 2 / Actual-- 6
# Index number of change-- 2071  /Pred-- 4 / Actual-- 3
# Index number of change-- 2073  /Pred-- 3 / Actual-- 4
# Index number of change-- 2090  /Pred-- 4 / Actual-- 2
# Index number of change-- 2106  /Pred-- 3 / Actual-- 2
# Index number of change-- 2109  /Pred-- 4 / Actual-- 2
# Index number of change-- 2150  /Pred-- 6 / Actual-- 4
# Index number of change-- 2161  /Pred-- 2 / Actual-- 4
# Index number of change-- 2162  /Pred-- 4 / Actual-- 6
# Index number of change-- 2169  /Pred-- 3 / Actual-- 1
# Index number of change-- 2181  /Pred-- 2 / Actual-- 8
# Index number of change-- 2189  /Pred-- 2 / Actual-- 4
# Index number of change-- 2190  /Pred-- 0 / Actual-- 6
# Index number of change-- 2195  /Pred-- 2 / Actual-- 6
# Index number of change-- 2221  /Pred-- 6 / Actual-- 0
# Index number of change-- 2247  /Pred-- 0 / Actual-- 6
# Index number of change-- 2272  /Pred-- 4 / Actual-- 2
# Index number of change-- 2278  /Pred-- 4 / Actual-- 2
# Index number of change-- 2284  /Pred-- 6 / Actual-- 4
# Index number of change-- 2290  /Pred-- 0 / Actual-- 6
# Index number of change-- 2300  /Pred-- 4 / Actual-- 6
# Index number of change-- 2305  /Pred-- 7 / Actual-- 5
# Index number of change-- 2311  /Pred-- 3 / Actual-- 6
# Index number of change-- 2312  /Pred-- 0 / Actual-- 3
# Index number of change-- 2316  /Pred-- 7 / Actual-- 9
# Index number of change-- 2326  /Pred-- 2 / Actual-- 6
# Index number of change-- 2332  /Pred-- 4 / Actual-- 2
# Index number of change-- 2337  /Pred-- 4 / Actual-- 2
# Index number of change-- 2347  /Pred-- 0 / Actual-- 3
# Index number of change-- 2351  /Pred-- 2 / Actual-- 6
# Index number of change-- 2373  /Pred-- 2 / Actual-- 6
# Index number of change-- 2376  /Pred-- 6 / Actual-- 4
# Index number of change-- 2396  /Pred-- 6 / Actual-- 1
# Index number of change-- 2397  /Pred-- 0 / Actual-- 6
# Index number of change-- 2404  /Pred-- 4 / Actual-- 6
# Index number of change-- 2418  /Pred-- 2 / Actual-- 4
# Index number of change-- 2419  /Pred-- 6 / Actual-- 3
# Index number of change-- 2421  /Pred-- 2 / Actual-- 4
# Index number of change-- 2425  /Pred-- 4 / Actual-- 6
# Index number of change-- 2431  /Pred-- 0 / Actual-- 6
# Index number of change-- 2462  /Pred-- 6 / Actual-- 4
# Index number of change-- 2464  /Pred-- 0 / Actual-- 6
# Index number of change-- 2469  /Pred-- 2 / Actual-- 6
# Index number of change-- 2476  /Pred-- 3 / Actual-- 8
# Index number of change-- 2478  /Pred-- 3 / Actual-- 1
# Index number of change-- 2487  /Pred-- 8 / Actual-- 4
# Index number of change-- 2498  /Pred-- 3 / Actual-- 6
# Index number of change-- 2500  /Pred-- 2 / Actual-- 6
# Index number of change-- 2503  /Pred-- 6 / Actual-- 2
# Index number of change-- 2506  /Pred-- 6 / Actual-- 0
# Index number of change-- 2507  /Pred-- 4 / Actual-- 3
# Index number of change-- 2509  /Pred-- 2 / Actual-- 4
# Index number of change-- 2527  /Pred-- 7 / Actual-- 9
# Index number of change-- 2540  /Pred-- 4 / Actual-- 6
# Index number of change-- 2548  /Pred-- 6 / Actual-- 2
# Index number of change-- 2559  /Pred-- 7 / Actual-- 9
# Index number of change-- 2570  /Pred-- 6 / Actual-- 4
# Index number of change-- 2571  /Pred-- 2 / Actual-- 0
# Index number of change-- 2573  /Pred-- 3 / Actual-- 4
# Index number of change-- 2578  /Pred-- 0 / Actual-- 6
# Index number of change-- 2580  /Pred-- 0 / Actual-- 6
# Index number of change-- 2590  /Pred-- 2 / Actual-- 4
# Index number of change-- 2599  /Pred-- 8 / Actual-- 0
# Index number of change-- 2608  /Pred-- 3 / Actual-- 4
# Index number of change-- 2615  /Pred-- 6 / Actual-- 2
# Index number of change-- 2622  /Pred-- 4 / Actual-- 6
# Index number of change-- 2628  /Pred-- 2 / Actual-- 0
# Index number of change-- 2629  /Pred-- 3 / Actual-- 6
# Index number of change-- 2639  /Pred-- 4 / Actual-- 3
# Index number of change-- 2641  /Pred-- 6 / Actual-- 0
# Index number of change-- 2652  /Pred-- 2 / Actual-- 0
# Index number of change-- 2653  /Pred-- 6 / Actual-- 0
# Index number of change-- 2659  /Pred-- 2 / Actual-- 8
# Index number of change-- 2661  /Pred-- 2 / Actual-- 6
# Index number of change-- 2670  /Pred-- 2 / Actual-- 6
# Index number of change-- 2671  /Pred-- 2 / Actual-- 4
# Index number of change-- 2678  /Pred-- 3 / Actual-- 4
# Index number of change-- 2681  /Pred-- 6 / Actual-- 4
# Index number of change-- 2685  /Pred-- 6 / Actual-- 3
# Index number of change-- 2689  /Pred-- 4 / Actual-- 6
# Index number of change-- 2690  /Pred-- 3 / Actual-- 4
# Index number of change-- 2694  /Pred-- 4 / Actual-- 6
# Index number of change-- 2695  /Pred-- 6 / Actual-- 3
# Index number of change-- 2717  /Pred-- 2 / Actual-- 0
# Index number of change-- 2721  /Pred-- 6 / Actual-- 3
# Index number of change-- 2727  /Pred-- 0 / Actual-- 3
# Index number of change-- 2732  /Pred-- 8 / Actual-- 6
# Index number of change-- 2734  /Pred-- 2 / Actual-- 4
# Index number of change-- 2737  /Pred-- 6 / Actual-- 4
# Index number of change-- 2739  /Pred-- 6 / Actual-- 1
# Index number of change-- 2741  /Pred-- 2 / Actual-- 1
# Index number of change-- 2751  /Pred-- 4 / Actual-- 2
# Index number of change-- 2752  /Pred-- 2 / Actual-- 6
# Index number of change-- 2757  /Pred-- 2 / Actual-- 6
# Index number of change-- 2776  /Pred-- 2 / Actual-- 4
# Index number of change-- 2779  /Pred-- 3 / Actual-- 4
# Index number of change-- 2782  /Pred-- 5 / Actual-- 7
# Index number of change-- 2798  /Pred-- 3 / Actual-- 4
# Index number of change-- 2811  /Pred-- 9 / Actual-- 7
# Index number of change-- 2817  /Pred-- 2 / Actual-- 3
# Index number of change-- 2824  /Pred-- 4 / Actual-- 3
# Index number of change-- 2839  /Pred-- 0 / Actual-- 6
# Index number of change-- 2840  /Pred-- 0 / Actual-- 6
# Index number of change-- 2842  /Pred-- 8 / Actual-- 6
# Index number of change-- 2843  /Pred-- 2 / Actual-- 6
# Index number of change-- 2856  /Pred-- 0 / Actual-- 6
# Index number of change-- 2860  /Pred-- 6 / Actual-- 3
# Index number of change-- 2865  /Pred-- 4 / Actual-- 6
# Index number of change-- 2869  /Pred-- 8 / Actual-- 6
# Index number of change-- 2872  /Pred-- 4 / Actual-- 0
# Index number of change-- 2880  /Pred-- 2 / Actual-- 6
# Index number of change-- 2882  /Pred-- 4 / Actual-- 6
# Index number of change-- 2883  /Pred-- 5 / Actual-- 7
# Index number of change-- 2891  /Pred-- 7 / Actual-- 5
# Index number of change-- 2894  /Pred-- 4 / Actual-- 2
# Index number of change-- 2897  /Pred-- 8 / Actual-- 0
# Index number of change-- 2898  /Pred-- 2 / Actual-- 3
# Index number of change-- 2900  /Pred-- 0 / Actual-- 3
# Index number of change-- 2905  /Pred-- 3 / Actual-- 8
# Index number of change-- 2909  /Pred-- 6 / Actual-- 0
# Index number of change-- 2914  /Pred-- 9 / Actual-- 7
# Index number of change-- 2920  /Pred-- 6 / Actual-- 2
# Index number of change-- 2926  /Pred-- 4 / Actual-- 2
# Index number of change-- 2935  /Pred-- 7 / Actual-- 9
# Index number of change-- 2939  /Pred-- 6 / Actual-- 4
# Index number of change-- 2940  /Pred-- 0 / Actual-- 6
# Index number of change-- 2942  /Pred-- 2 / Actual-- 6
# Index number of change-- 2951  /Pred-- 3 / Actual-- 1
# Index number of change-- 2953  /Pred-- 3 / Actual-- 0
# Index number of change-- 2956  /Pred-- 6 / Actual-- 2
# Index number of change-- 2960  /Pred-- 0 / Actual-- 2
# Index number of change-- 2965  /Pred-- 9 / Actual-- 7
# Index number of change-- 2985  /Pred-- 2 / Actual-- 6
# Index number of change-- 2986  /Pred-- 0 / Actual-- 6
# Index number of change-- 2997  /Pred-- 3 / Actual-- 0
# Index number of change-- 2998  /Pred-- 4 / Actual-- 6
# Index number of change-- 3007  /Pred-- 6 / Actual-- 3
# Index number of change-- 3008  /Pred-- 3 / Actual-- 8
# Index number of change-- 3019  /Pred-- 6 / Actual-- 3
# Index number of change-- 3020  /Pred-- 0 / Actual-- 6
# Index number of change-- 3045  /Pred-- 3 / Actual-- 6
# Index number of change-- 3080  /Pred-- 0 / Actual-- 6
# Index number of change-- 3081  /Pred-- 2 / Actual-- 4
# Index number of change-- 3084  /Pred-- 3 / Actual-- 4
# Index number of change-- 3101  /Pred-- 0 / Actual-- 6
# Index number of change-- 3103  /Pred-- 3 / Actual-- 4
# Index number of change-- 3110  /Pred-- 2 / Actual-- 4
# Index number of change-- 3111  /Pred-- 9 / Actual-- 7
# Index number of change-- 3116  /Pred-- 4 / Actual-- 6
# Index number of change-- 3132  /Pred-- 2 / Actual-- 0
# Index number of change-- 3165  /Pred-- 2 / Actual-- 6
# Index number of change-- 3174  /Pred-- 2 / Actual-- 6
# Index number of change-- 3176  /Pred-- 6 / Actual-- 4
# Index number of change-- 3181  /Pred-- 6 / Actual-- 4
# Index number of change-- 3188  /Pred-- 2 / Actual-- 6
# Index number of change-- 3190  /Pred-- 4 / Actual-- 2
# Index number of change-- 3198  /Pred-- 4 / Actual-- 6
# Index number of change-- 3202  /Pred-- 9 / Actual-- 7
# Index number of change-- 3203  /Pred-- 2 / Actual-- 6
# Index number of change-- 3205  /Pred-- 3 / Actual-- 0
# Index number of change-- 3209  /Pred-- 6 / Actual-- 3
# Index number of change-- 3216  /Pred-- 2 / Actual-- 9
# Index number of change-- 3219  /Pred-- 7 / Actual-- 5
# Index number of change-- 3229  /Pred-- 2 / Actual-- 4
# Index number of change-- 3230  /Pred-- 0 / Actual-- 6
# Index number of change-- 3232  /Pred-- 0 / Actual-- 6
# Index number of change-- 3234  /Pred-- 5 / Actual-- 7
# Index number of change-- 3238  /Pred-- 9 / Actual-- 7
# Index number of change-- 3239  /Pred-- 0 / Actual-- 6
# Index number of change-- 3240  /Pred-- 6 / Actual-- 2
# Index number of change-- 3255  /Pred-- 0 / Actual-- 2
# Index number of change-- 3256  /Pred-- 5 / Actual-- 7
# Index number of change-- 3262  /Pred-- 2 / Actual-- 6
# Index number of change-- 3265  /Pred-- 2 / Actual-- 3
# Index number of change-- 3282  /Pred-- 6 / Actual-- 8
# Index number of change-- 3290  /Pred-- 2 / Actual-- 4
# Index number of change-- 3295  /Pred-- 2 / Actual-- 4
# Index number of change-- 3297  /Pred-- 4 / Actual-- 2
# Index number of change-- 3301  /Pred-- 6 / Actual-- 2
# Index number of change-- 3311  /Pred-- 8 / Actual-- 0
# Index number of change-- 3313  /Pred-- 6 / Actual-- 3
# Index number of change-- 3322  /Pred-- 0 / Actual-- 3
# Index number of change-- 3323  /Pred-- 0 / Actual-- 6
# Index number of change-- 3325  /Pred-- 2 / Actual-- 4
# Index number of change-- 3327  /Pred-- 0 / Actual-- 6
# Index number of change-- 3334  /Pred-- 3 / Actual-- 6
# Index number of change-- 3338  /Pred-- 1 / Actual-- 6
# Index number of change-- 3342  /Pred-- 6 / Actual-- 0
# Index number of change-- 3351  /Pred-- 9 / Actual-- 7
# Index number of change-- 3365  /Pred-- 4 / Actual-- 2
# Index number of change-- 3370  /Pred-- 4 / Actual-- 2
# Index number of change-- 3386  /Pred-- 2 / Actual-- 4
# Index number of change-- 3393  /Pred-- 2 / Actual-- 6
# Index number of change-- 3416  /Pred-- 0 / Actual-- 6
# Index number of change-- 3429  /Pred-- 0 / Actual-- 6
# Index number of change-- 3436  /Pred-- 0 / Actual-- 3
# Index number of change-- 3438  /Pred-- 6 / Actual-- 2
# Index number of change-- 3439  /Pred-- 9 / Actual-- 7
# Index number of change-- 3442  /Pred-- 5 / Actual-- 7
# Index number of change-- 3451  /Pred-- 6 / Actual-- 0
# Index number of change-- 3453  /Pred-- 4 / Actual-- 2
# Index number of change-- 3454  /Pred-- 6 / Actual-- 0
# Index number of change-- 3457  /Pred-- 4 / Actual-- 2
# Index number of change-- 3466  /Pred-- 5 / Actual-- 0
# Index number of change-- 3468  /Pred-- 9 / Actual-- 8
# Index number of change-- 3481  /Pred-- 3 / Actual-- 6
# Index number of change-- 3484  /Pred-- 6 / Actual-- 0
# Index number of change-- 3485  /Pred-- 3 / Actual-- 0
# Index number of change-- 3487  /Pred-- 9 / Actual-- 5
# Index number of change-- 3488  /Pred-- 0 / Actual-- 6
# Index number of change-- 3489  /Pred-- 3 / Actual-- 2
# Index number of change-- 3491  /Pred-- 4 / Actual-- 6
# Index number of change-- 3496  /Pred-- 4 / Actual-- 2
# Index number of change-- 3497  /Pred-- 0 / Actual-- 6
# Index number of change-- 3501  /Pred-- 4 / Actual-- 2
# Index number of change-- 3509  /Pred-- 2 / Actual-- 4
# Index number of change-- 3526  /Pred-- 4 / Actual-- 2
# Index number of change-- 3531  /Pred-- 3 / Actual-- 0
# Index number of change-- 3532  /Pred-- 6 / Actual-- 2
# Index number of change-- 3534  /Pred-- 4 / Actual-- 2
# Index number of change-- 3540  /Pred-- 6 / Actual-- 0
# Index number of change-- 3545  /Pred-- 2 / Actual-- 6
# Index number of change-- 3548  /Pred-- 4 / Actual-- 6
# Index number of change-- 3553  /Pred-- 0 / Actual-- 2
# Index number of change-- 3554  /Pred-- 4 / Actual-- 2
# Index number of change-- 3568  /Pred-- 2 / Actual-- 4
# Index number of change-- 3572  /Pred-- 2 / Actual-- 6
# Index number of change-- 3575  /Pred-- 6 / Actual-- 0
# Index number of change-- 3585  /Pred-- 6 / Actual-- 2
# Index number of change-- 3586  /Pred-- 6 / Actual-- 0
# Index number of change-- 3598  /Pred-- 4 / Actual-- 2
# Index number of change-- 3609  /Pred-- 8 / Actual-- 0
# Index number of change-- 3613  /Pred-- 0 / Actual-- 6
# Index number of change-- 3625  /Pred-- 0 / Actual-- 6
# Index number of change-- 3626  /Pred-- 3 / Actual-- 4
# Index number of change-- 3639  /Pred-- 3 / Actual-- 4
# Index number of change-- 3649  /Pred-- 6 / Actual-- 4
# Index number of change-- 3658  /Pred-- 4 / Actual-- 6
# Index number of change-- 3664  /Pred-- 9 / Actual-- 7
# Index number of change-- 3669  /Pred-- 4 / Actual-- 6
# Index number of change-- 3674  /Pred-- 7 / Actual-- 9
# Index number of change-- 3704  /Pred-- 6 / Actual-- 4
# Index number of change-- 3706  /Pred-- 4 / Actual-- 3
# Index number of change-- 3714  /Pred-- 6 / Actual-- 2
# Index number of change-- 3724  /Pred-- 0 / Actual-- 6
# Index number of change-- 3730  /Pred-- 3 / Actual-- 4
# Index number of change-- 3731  /Pred-- 2 / Actual-- 4
# Index number of change-- 3741  /Pred-- 8 / Actual-- 6
# Index number of change-- 3747  /Pred-- 6 / Actual-- 0
# Index number of change-- 3763  /Pred-- 4 / Actual-- 2
# Index number of change-- 3779  /Pred-- 0 / Actual-- 3
# Index number of change-- 3787  /Pred-- 2 / Actual-- 6
# Index number of change-- 3800  /Pred-- 2 / Actual-- 6
# Index number of change-- 3804  /Pred-- 3 / Actual-- 4
# Index number of change-- 3805  /Pred-- 1 / Actual-- 3
# Index number of change-- 3808  /Pred-- 2 / Actual-- 6
# Index number of change-- 3809  /Pred-- 2 / Actual-- 4
# Index number of change-- 3811  /Pred-- 3 / Actual-- 4
# Index number of change-- 3816  /Pred-- 4 / Actual-- 2
# Index number of change-- 3825  /Pred-- 5 / Actual-- 7
# Index number of change-- 3826  /Pred-- 2 / Actual-- 1
# Index number of change-- 3829  /Pred-- 3 / Actual-- 6
# Index number of change-- 3830  /Pred-- 3 / Actual-- 6
# Index number of change-- 3861  /Pred-- 8 / Actual-- 6
# Index number of change-- 3864  /Pred-- 2 / Actual-- 6
# Index number of change-- 3865  /Pred-- 6 / Actual-- 2
# Index number of change-- 3866  /Pred-- 9 / Actual-- 5
# Index number of change-- 3871  /Pred-- 4 / Actual-- 2
# Index number of change-- 3880  /Pred-- 3 / Actual-- 2
# Index number of change-- 3881  /Pred-- 8 / Actual-- 6
# Index number of change-- 3884  /Pred-- 0 / Actual-- 6
# Index number of change-- 3892  /Pred-- 2 / Actual-- 4
# Index number of change-- 3895  /Pred-- 3 / Actual-- 0
# Index number of change-- 3896  /Pred-- 7 / Actual-- 9
# Index number of change-- 3900  /Pred-- 2 / Actual-- 6
# Index number of change-- 3906  /Pred-- 0 / Actual-- 6
# Index number of change-- 3919  /Pred-- 8 / Actual-- 0
# Index number of change-- 3926  /Pred-- 4 / Actual-- 6
# Index number of change-- 3933  /Pred-- 4 / Actual-- 2
# Index number of change-- 3938  /Pred-- 2 / Actual-- 0
# Index number of change-- 3946  /Pred-- 3 / Actual-- 0
# Index number of change-- 3953  /Pred-- 6 / Actual-- 0
# Index number of change-- 3961  /Pred-- 2 / Actual-- 4
# Index number of change-- 3973  /Pred-- 4 / Actual-- 3
# Index number of change-- 3974  /Pred-- 3 / Actual-- 1
# Index number of change-- 3977  /Pred-- 5 / Actual-- 7
# Index number of change-- 3984  /Pred-- 2 / Actual-- 4
# Index number of change-- 3987  /Pred-- 4 / Actual-- 6
# Index number of change-- 3988  /Pred-- 2 / Actual-- 8
# Index number of change-- 3999  /Pred-- 5 / Actual-- 9
# Index number of change-- 4012  /Pred-- 2 / Actual-- 4
# Index number of change-- 4019  /Pred-- 0 / Actual-- 6
# Index number of change-- 4021  /Pred-- 4 / Actual-- 2
# Index number of change-- 4025  /Pred-- 6 / Actual-- 4
# Index number of change-- 4035  /Pred-- 0 / Actual-- 6
# Index number of change-- 4037  /Pred-- 4 / Actual-- 2
# Index number of change-- 4040  /Pred-- 7 / Actual-- 5
# Index number of change-- 4041  /Pred-- 3 / Actual-- 2
# Index number of change-- 4058  /Pred-- 9 / Actual-- 7
# Index number of change-- 4064  /Pred-- 4 / Actual-- 2
# Index number of change-- 4071  /Pred-- 0 / Actual-- 8
# Index number of change-- 4074  /Pred-- 6 / Actual-- 2
# Index number of change-- 4079  /Pred-- 4 / Actual-- 6
# Index number of change-- 4081  /Pred-- 6 / Actual-- 2
# Index number of change-- 4082  /Pred-- 0 / Actual-- 6
# Index number of change-- 4084  /Pred-- 0 / Actual-- 3
# Index number of change-- 4088  /Pred-- 2 / Actual-- 6
# Index number of change-- 4108  /Pred-- 6 / Actual-- 0
# Index number of change-- 4109  /Pred-- 0 / Actual-- 6
# Index number of change-- 4127  /Pred-- 0 / Actual-- 6
# Index number of change-- 4132  /Pred-- 8 / Actual-- 9
# Index number of change-- 4142  /Pred-- 0 / Actual-- 6
# Index number of change-- 4143  /Pred-- 2 / Actual-- 0
# Index number of change-- 4148  /Pred-- 0 / Actual-- 3
# Index number of change-- 4152  /Pred-- 2 / Actual-- 6
# Index number of change-- 4153  /Pred-- 0 / Actual-- 6
# Index number of change-- 4159  /Pred-- 0 / Actual-- 2
# Index number of change-- 4160  /Pred-- 4 / Actual-- 2
# Index number of change-- 4173  /Pred-- 6 / Actual-- 4
# Index number of change-- 4184  /Pred-- 9 / Actual-- 7
# Index number of change-- 4192  /Pred-- 0 / Actual-- 6
# Index number of change-- 4194  /Pred-- 0 / Actual-- 6
# Index number of change-- 4217  /Pred-- 4 / Actual-- 2
# Index number of change-- 4218  /Pred-- 3 / Actual-- 8
# Index number of change-- 4231  /Pred-- 0 / Actual-- 6
# Index number of change-- 4233  /Pred-- 2 / Actual-- 4
# Index number of change-- 4251  /Pred-- 1 / Actual-- 4
# Index number of change-- 4262  /Pred-- 3 / Actual-- 0
# Index number of change-- 4267  /Pred-- 2 / Actual-- 6
# Index number of change-- 4271  /Pred-- 0 / Actual-- 6
# Index number of change-- 4272  /Pred-- 2 / Actual-- 4
# Index number of change-- 4300  /Pred-- 6 / Actual-- 2
# Index number of change-- 4307  /Pred-- 3 / Actual-- 4
# Index number of change-- 4317  /Pred-- 2 / Actual-- 4
# Index number of change-- 4328  /Pred-- 2 / Actual-- 4
# Index number of change-- 4333  /Pred-- 6 / Actual-- 4
# Index number of change-- 4365  /Pred-- 0 / Actual-- 6
# Index number of change-- 4389  /Pred-- 2 / Actual-- 4
# Index number of change-- 4394  /Pred-- 8 / Actual-- 3
# Index number of change-- 4404  /Pred-- 7 / Actual-- 9
# Index number of change-- 4405  /Pred-- 7 / Actual-- 5
# Index number of change-- 4413  /Pred-- 0 / Actual-- 6
# Index number of change-- 4417  /Pred-- 6 / Actual-- 4
# Index number of change-- 4429  /Pred-- 2 / Actual-- 6
# Index number of change-- 4453  /Pred-- 0 / Actual-- 6
# Index number of change-- 4462  /Pred-- 1 / Actual-- 3
# Index number of change-- 4465  /Pred-- 6 / Actual-- 2
# Index number of change-- 4471  /Pred-- 2 / Actual-- 4
# Index number of change-- 4481  /Pred-- 2 / Actual-- 4
# Index number of change-- 4484  /Pred-- 3 / Actual-- 4
# Index number of change-- 4495  /Pred-- 6 / Actual-- 2
# Index number of change-- 4505  /Pred-- 0 / Actual-- 6
# Index number of change-- 4509  /Pred-- 3 / Actual-- 6
# Index number of change-- 4539  /Pred-- 3 / Actual-- 0
# Index number of change-- 4559  /Pred-- 2 / Actual-- 4
# Index number of change-- 4569  /Pred-- 3 / Actual-- 6
# Index number of change-- 4599  /Pred-- 9 / Actual-- 5
# Index number of change-- 4608  /Pred-- 6 / Actual-- 4
# Index number of change-- 4615  /Pred-- 5 / Actual-- 9
# Index number of change-- 4623  /Pred-- 6 / Actual-- 0
# Index number of change-- 4641  /Pred-- 2 / Actual-- 4
# Index number of change-- 4642  /Pred-- 2 / Actual-- 6
# Index number of change-- 4646  /Pred-- 2 / Actual-- 4
# Index number of change-- 4649  /Pred-- 4 / Actual-- 2
# Index number of change-- 4652  /Pred-- 2 / Actual-- 4
# Index number of change-- 4658  /Pred-- 3 / Actual-- 0
# Index number of change-- 4664  /Pred-- 4 / Actual-- 3
# Index number of change-- 4668  /Pred-- 2 / Actual-- 4
# Index number of change-- 4672  /Pred-- 2 / Actual-- 6
# Index number of change-- 4677  /Pred-- 4 / Actual-- 6
# Index number of change-- 4681  /Pred-- 9 / Actual-- 7
# Index number of change-- 4685  /Pred-- 6 / Actual-- 2
# Index number of change-- 4692  /Pred-- 0 / Actual-- 6
# Index number of change-- 4724  /Pred-- 0 / Actual-- 6
# Index number of change-- 4726  /Pred-- 3 / Actual-- 4
# Index number of change-- 4727  /Pred-- 0 / Actual-- 6
# Index number of change-- 4738  /Pred-- 4 / Actual-- 2
# Index number of change-- 4742  /Pred-- 9 / Actual-- 5
# Index number of change-- 4743  /Pred-- 5 / Actual-- 9
# Index number of change-- 4750  /Pred-- 7 / Actual-- 5
# Index number of change-- 4751  /Pred-- 4 / Actual-- 3
# Index number of change-- 4758  /Pred-- 0 / Actual-- 6
# Index number of change-- 4763  /Pred-- 0 / Actual-- 6
# Index number of change-- 4775  /Pred-- 6 / Actual-- 4
# Index number of change-- 4784  /Pred-- 0 / Actual-- 6
# Index number of change-- 4803  /Pred-- 0 / Actual-- 6
# Index number of change-- 4810  /Pred-- 2 / Actual-- 4
# Index number of change-- 4817  /Pred-- 4 / Actual-- 6
# Index number of change-- 4823  /Pred-- 4 / Actual-- 2
# Index number of change-- 4828  /Pred-- 4 / Actual-- 2
# Index number of change-- 4829  /Pred-- 7 / Actual-- 8
# Index number of change-- 4836  /Pred-- 8 / Actual-- 6
# Index number of change-- 4842  /Pred-- 0 / Actual-- 6
# Index number of change-- 4845  /Pred-- 0 / Actual-- 6
# Index number of change-- 4846  /Pred-- 6 / Actual-- 2
# Index number of change-- 4847  /Pred-- 4 / Actual-- 2
# Index number of change-- 4850  /Pred-- 7 / Actual-- 9
# Index number of change-- 4880  /Pred-- 2 / Actual-- 4
# Index number of change-- 4882  /Pred-- 4 / Actual-- 2
# Index number of change-- 4885  /Pred-- 7 / Actual-- 9
# Index number of change-- 4896  /Pred-- 0 / Actual-- 6
# Index number of change-- 4907  /Pred-- 3 / Actual-- 4
# Index number of change-- 4920  /Pred-- 9 / Actual-- 7
# Index number of change-- 4932  /Pred-- 2 / Actual-- 4
# Index number of change-- 4934  /Pred-- 6 / Actual-- 3
# Index number of change-- 4937  /Pred-- 9 / Actual-- 7
# Index number of change-- 4941  /Pred-- 4 / Actual-- 6
# Index number of change-- 4948  /Pred-- 7 / Actual-- 5
# Index number of change-- 4956  /Pred-- 4 / Actual-- 2
# Index number of change-- 4973  /Pred-- 6 / Actual-- 0
# Index number of change-- 4981  /Pred-- 0 / Actual-- 3
# Index number of change-- 4985  /Pred-- 6 / Actual-- 2
# Index number of change-- 4995  /Pred-- 2 / Actual-- 4
# Index number of change-- 5002  /Pred-- 0 / Actual-- 6
# Index number of change-- 5004  /Pred-- 4 / Actual-- 6
# Index number of change-- 5006  /Pred-- 3 / Actual-- 6
# Index number of change-- 5009  /Pred-- 7 / Actual-- 9
# Index number of change-- 5012  /Pred-- 2 / Actual-- 3
# Index number of change-- 5030  /Pred-- 8 / Actual-- 0
# Index number of change-- 5032  /Pred-- 6 / Actual-- 0
# Index number of change-- 5036  /Pred-- 3 / Actual-- 4
# Index number of change-- 5046  /Pred-- 2 / Actual-- 4
# Index number of change-- 5052  /Pred-- 4 / Actual-- 6
# Index number of change-- 5065  /Pred-- 8 / Actual-- 6
# Index number of change-- 5066  /Pred-- 2 / Actual-- 4
# Index number of change-- 5070  /Pred-- 3 / Actual-- 4
# Index number of change-- 5077  /Pred-- 7 / Actual-- 9
# Index number of change-- 5086  /Pred-- 6 / Actual-- 0
# Index number of change-- 5088  /Pred-- 0 / Actual-- 6
# Index number of change-- 5094  /Pred-- 5 / Actual-- 9
# Index number of change-- 5096  /Pred-- 4 / Actual-- 6
# Index number of change-- 5100  /Pred-- 2 / Actual-- 4
# Index number of change-- 5108  /Pred-- 3 / Actual-- 6
# Index number of change-- 5119  /Pred-- 6 / Actual-- 0
# Index number of change-- 5121  /Pred-- 0 / Actual-- 3
# Index number of change-- 5123  /Pred-- 8 / Actual-- 6
# Index number of change-- 5125  /Pred-- 4 / Actual-- 2
# Index number of change-- 5135  /Pred-- 0 / Actual-- 6
# Index number of change-- 5144  /Pred-- 6 / Actual-- 0
# Index number of change-- 5148  /Pred-- 4 / Actual-- 8
# Index number of change-- 5155  /Pred-- 2 / Actual-- 6
# Index number of change-- 5161  /Pred-- 4 / Actual-- 6
# Index number of change-- 5164  /Pred-- 7 / Actual-- 9
# Index number of change-- 5167  /Pred-- 2 / Actual-- 4
# Index number of change-- 5168  /Pred-- 4 / Actual-- 6
# Index number of change-- 5172  /Pred-- 3 / Actual-- 0
# Index number of change-- 5178  /Pred-- 5 / Actual-- 7
# Index number of change-- 5184  /Pred-- 2 / Actual-- 6
# Index number of change-- 5186  /Pred-- 0 / Actual-- 6
# Index number of change-- 5197  /Pred-- 2 / Actual-- 6
# Index number of change-- 5204  /Pred-- 2 / Actual-- 3
# Index number of change-- 5210  /Pred-- 5 / Actual-- 7
# Index number of change-- 5228  /Pred-- 2 / Actual-- 6
# Index number of change-- 5248  /Pred-- 3 / Actual-- 6
# Index number of change-- 5249  /Pred-- 3 / Actual-- 6
# Index number of change-- 5254  /Pred-- 4 / Actual-- 6
# Index number of change-- 5255  /Pred-- 2 / Actual-- 4
# Index number of change-- 5260  /Pred-- 2 / Actual-- 6
# Index number of change-- 5270  /Pred-- 0 / Actual-- 3
# Index number of change-- 5282  /Pred-- 2 / Actual-- 6
# Index number of change-- 5297  /Pred-- 6 / Actual-- 0
# Index number of change-- 5304  /Pred-- 3 / Actual-- 4
# Index number of change-- 5307  /Pred-- 6 / Actual-- 0
# Index number of change-- 5310  /Pred-- 6 / Actual-- 4
# Index number of change-- 5316  /Pred-- 9 / Actual-- 7
# Index number of change-- 5317  /Pred-- 3 / Actual-- 0
# Index number of change-- 5327  /Pred-- 3 / Actual-- 1
# Index number of change-- 5334  /Pred-- 3 / Actual-- 0
# Index number of change-- 5336  /Pred-- 2 / Actual-- 4
# Index number of change-- 5338  /Pred-- 8 / Actual-- 0
# Index number of change-- 5345  /Pred-- 0 / Actual-- 6
# Index number of change-- 5368  /Pred-- 3 / Actual-- 8
# Index number of change-- 5381  /Pred-- 2 / Actual-- 4
# Index number of change-- 5382  /Pred-- 3 / Actual-- 4
# Index number of change-- 5391  /Pred-- 2 / Actual-- 4
# Index number of change-- 5397  /Pred-- 2 / Actual-- 4
# Index number of change-- 5424  /Pred-- 3 / Actual-- 6
# Index number of change-- 5435  /Pred-- 6 / Actual-- 0
# Index number of change-- 5438  /Pred-- 0 / Actual-- 6
# Index number of change-- 5441  /Pred-- 2 / Actual-- 4
# Index number of change-- 5442  /Pred-- 3 / Actual-- 6
# Index number of change-- 5452  /Pred-- 2 / Actual-- 6
# Index number of change-- 5468  /Pred-- 0 / Actual-- 2
# Index number of change-- 5469  /Pred-- 0 / Actual-- 6
# Index number of change-- 5470  /Pred-- 4 / Actual-- 8
# Index number of change-- 5471  /Pred-- 6 / Actual-- 2
# Index number of change-- 5476  /Pred-- 7 / Actual-- 9
# Index number of change-- 5482  /Pred-- 6 / Actual-- 4
# Index number of change-- 5488  /Pred-- 0 / Actual-- 3
# Index number of change-- 5497  /Pred-- 2 / Actual-- 6
# Index number of change-- 5510  /Pred-- 8 / Actual-- 6
# Index number of change-- 5511  /Pred-- 2 / Actual-- 4
# Index number of change-- 5512  /Pred-- 8 / Actual-- 9
# Index number of change-- 5517  /Pred-- 7 / Actual-- 9
# Index number of change-- 5520  /Pred-- 9 / Actual-- 7
# Index number of change-- 5521  /Pred-- 2 / Actual-- 6
# Index number of change-- 5522  /Pred-- 0 / Actual-- 6
# Index number of change-- 5525  /Pred-- 7 / Actual-- 9
# Index number of change-- 5533  /Pred-- 3 / Actual-- 1
# Index number of change-- 5546  /Pred-- 2 / Actual-- 4
# Index number of change-- 5561  /Pred-- 3 / Actual-- 5
# Index number of change-- 5563  /Pred-- 7 / Actual-- 5
# Index number of change-- 5568  /Pred-- 4 / Actual-- 2
# Index number of change-- 5569  /Pred-- 3 / Actual-- 6
# Index number of change-- 5575  /Pred-- 4 / Actual-- 3
# Index number of change-- 5576  /Pred-- 4 / Actual-- 3
# Index number of change-- 5583  /Pred-- 3 / Actual-- 4
# Index number of change-- 5592  /Pred-- 2 / Actual-- 3
# Index number of change-- 5594  /Pred-- 2 / Actual-- 6
# Index number of change-- 5596  /Pred-- 4 / Actual-- 6
# Index number of change-- 5597  /Pred-- 3 / Actual-- 1
# Index number of change-- 5601  /Pred-- 6 / Actual-- 0
# Index number of change-- 5605  /Pred-- 2 / Actual-- 4
# Index number of change-- 5617  /Pred-- 4 / Actual-- 2
# Index number of change-- 5623  /Pred-- 2 / Actual-- 6
# Index number of change-- 5628  /Pred-- 2 / Actual-- 4
# Index number of change-- 5629  /Pred-- 4 / Actual-- 6
# Index number of change-- 5634  /Pred-- 0 / Actual-- 6
# Index number of change-- 5636  /Pred-- 4 / Actual-- 6
# Index number of change-- 5648  /Pred-- 2 / Actual-- 6
# Index number of change-- 5652  /Pred-- 6 / Actual-- 2
# Index number of change-- 5654  /Pred-- 0 / Actual-- 6
# Index number of change-- 5655  /Pred-- 3 / Actual-- 1
# Index number of change-- 5657  /Pred-- 4 / Actual-- 2
# Index number of change-- 5661  /Pred-- 3 / Actual-- 4
# Index number of change-- 5685  /Pred-- 9 / Actual-- 5
# Index number of change-- 5689  /Pred-- 7 / Actual-- 5
# Index number of change-- 5695  /Pred-- 0 / Actual-- 6
# Index number of change-- 5701  /Pred-- 6 / Actual-- 2
# Index number of change-- 5703  /Pred-- 9 / Actual-- 5
# Index number of change-- 5710  /Pred-- 6 / Actual-- 2
# Index number of change-- 5713  /Pred-- 0 / Actual-- 2
# Index number of change-- 5718  /Pred-- 3 / Actual-- 0
# Index number of change-- 5721  /Pred-- 6 / Actual-- 4
# Index number of change-- 5734  /Pred-- 8 / Actual-- 2
# Index number of change-- 5737  /Pred-- 9 / Actual-- 7
# Index number of change-- 5739  /Pred-- 3 / Actual-- 0
# Index number of change-- 5742  /Pred-- 2 / Actual-- 4
# Index number of change-- 5745  /Pred-- 6 / Actual-- 0
# Index number of change-- 5746  /Pred-- 3 / Actual-- 1
# Index number of change-- 5749  /Pred-- 4 / Actual-- 6
# Index number of change-- 5752  /Pred-- 4 / Actual-- 2
# Index number of change-- 5756  /Pred-- 0 / Actual-- 6
# Index number of change-- 5762  /Pred-- 2 / Actual-- 4
# Index number of change-- 5763  /Pred-- 1 / Actual-- 3
# Index number of change-- 5791  /Pred-- 2 / Actual-- 4
# Index number of change-- 5795  /Pred-- 4 / Actual-- 6
# Index number of change-- 5804  /Pred-- 4 / Actual-- 2
# Index number of change-- 5806  /Pred-- 0 / Actual-- 6
# Index number of change-- 5813  /Pred-- 5 / Actual-- 7
# Index number of change-- 5816  /Pred-- 2 / Actual-- 6
# Index number of change-- 5820  /Pred-- 0 / Actual-- 2
# Index number of change-- 5826  /Pred-- 4 / Actual-- 6
# Index number of change-- 5840  /Pred-- 0 / Actual-- 3
# Index number of change-- 5849  /Pred-- 2 / Actual-- 4
# Index number of change-- 5853  /Pred-- 4 / Actual-- 2
# Index number of change-- 5881  /Pred-- 6 / Actual-- 4
# Index number of change-- 5885  /Pred-- 4 / Actual-- 6
# Index number of change-- 5889  /Pred-- 2 / Actual-- 6
# Index number of change-- 5896  /Pred-- 2 / Actual-- 4
# Index number of change-- 5899  /Pred-- 7 / Actual-- 5
# Index number of change-- 5928  /Pred-- 7 / Actual-- 5
# Index number of change-- 5934  /Pred-- 4 / Actual-- 2
# Index number of change-- 5938  /Pred-- 7 / Actual-- 9
# Index number of change-- 5946  /Pred-- 5 / Actual-- 9
# Index number of change-- 5956  /Pred-- 4 / Actual-- 2
# Index number of change-- 5965  /Pred-- 2 / Actual-- 4
# Index number of change-- 5966  /Pred-- 3 / Actual-- 0
# Index number of change-- 5967  /Pred-- 4 / Actual-- 3
# Index number of change-- 5971  /Pred-- 4 / Actual-- 3
# Index number of change-- 5974  /Pred-- 6 / Actual-- 2
# Index number of change-- 5981  /Pred-- 0 / Actual-- 4
# Index number of change-- 5987  /Pred-- 3 / Actual-- 6
# Index number of change-- 6002  /Pred-- 4 / Actual-- 6
# Index number of change-- 6007  /Pred-- 3 / Actual-- 4
# Index number of change-- 6008  /Pred-- 0 / Actual-- 6
# Index number of change-- 6010  /Pred-- 7 / Actual-- 5
# Index number of change-- 6012  /Pred-- 4 / Actual-- 3
# Index number of change-- 6020  /Pred-- 0 / Actual-- 6
# Index number of change-- 6023  /Pred-- 0 / Actual-- 6
# Index number of change-- 6024  /Pred-- 0 / Actual-- 6
# Index number of change-- 6025  /Pred-- 4 / Actual-- 2
# Index number of change-- 6026  /Pred-- 2 / Actual-- 6
# Index number of change-- 6027  /Pred-- 6 / Actual-- 2
# Index number of change-- 6032  /Pred-- 4 / Actual-- 2
# Index number of change-- 6037  /Pred-- 2 / Actual-- 6
# Index number of change-- 6061  /Pred-- 9 / Actual-- 5
# Index number of change-- 6085  /Pred-- 9 / Actual-- 7
# Index number of change-- 6086  /Pred-- 4 / Actual-- 2
# Index number of change-- 6096  /Pred-- 2 / Actual-- 6
# Index number of change-- 6103  /Pred-- 0 / Actual-- 4
# ...
# Index number of change-- 7945  /Pred-- 2 / Actual-- 4
# Index number of change-- 7948  /Pred-- 4 / Actual-- 3
# Index number of change-- 7959  /Pred-- 0 / Actual-- 6
# Index number of change-- 7962  /Pred-- 4 / Actual-- 6
# Index number of change-- 7965  /Pred-- 2 / Actual-- 4
# Index number of change-- 7971  /Pred-- 2 / Actual-- 6
# Index number of change-- 7975  /Pred-- 3 / Actual-- 0
# Index number of change-- 7976  /Pred-- 4 / Actual-- 2
# Index number of change-- 7983  /Pred-- 7 / Actual-- 9
# Index number of change-- 7986  /Pred-- 3 / Actual-- 4
# Index number of change-- 7992  /Pred-- 4 / Actual-- 6
# Index number of change-- 7998  /Pred-- 0 / Actual-- 2
# Index number of change-- 8001  /Pred-- 4 / Actual-- 2
# Index number of change-- 8004  /Pred-- 4 / Actual-- 6
# Index number of change-- 8005  /Pred-- 4 / Actual-- 6
# Index number of change-- 8006  /Pred-- 4 / Actual-- 2
# Index number of change-- 8007  /Pred-- 6 / Actual-- 0
# Index number of change-- 8009  /Pred-- 8 / Actual-- 2
# Index number of change-- 8031  /Pred-- 6 / Actual-- 0
# Index number of change-- 8033  /Pred-- 0 / Actual-- 6
# Index number of change-- 8035  /Pred-- 2 / Actual-- 6
# Index number of change-- 8039  /Pred-- 3 / Actual-- 4
# Index number of change-- 8051  /Pred-- 6 / Actual-- 2
# Index number of change-- 8054  /Pred-- 6 / Actual-- 3
# Index number of change-- 8058  /Pred-- 4 / Actual-- 2
# Index number of change-- 8059  /Pred-- 6 / Actual-- 0
# Index number of change-- 8061  /Pred-- 5 / Actual-- 9
# Index number of change-- 8074  /Pred-- 3 / Actual-- 1
# Index number of change-- 8085  /Pred-- 6 / Actual-- 4
# Index number of change-- 8111  /Pred-- 0 / Actual-- 3
# Index number of change-- 8132  /Pred-- 2 / Actual-- 6
# Index number of change-- 8137  /Pred-- 3 / Actual-- 0
# Index number of change-- 8148  /Pred-- 2 / Actual-- 6
# Index number of change-- 8154  /Pred-- 2 / Actual-- 4
# Index number of change-- 8156  /Pred-- 8 / Actual-- 1
# Index number of change-- 8178  /Pred-- 2 / Actual-- 4
# Index number of change-- 8193  /Pred-- 0 / Actual-- 6
# Index number of change-- 8202  /Pred-- 4 / Actual-- 6
# Index number of change-- 8204  /Pred-- 2 / Actual-- 3
# Index number of change-- 8205  /Pred-- 7 / Actual-- 9
# Index number of change-- 8208  /Pred-- 2 / Actual-- 8
# Index number of change-- 8211  /Pred-- 8 / Actual-- 6
# Index number of change-- 8217  /Pred-- 2 / Actual-- 6
# Index number of change-- 8226  /Pred-- 6 / Actual-- 2
# Index number of change-- 8237  /Pred-- 0 / Actual-- 6
# Index number of change-- 8239  /Pred-- 2 / Actual-- 4
# Index number of change-- 8259  /Pred-- 0 / Actual-- 3
# Index number of change-- 8260  /Pred-- 4 / Actual-- 6
# Index number of change-- 8275  /Pred-- 2 / Actual-- 6
# Index number of change-- 8287  /Pred-- 6 / Actual-- 8
# Index number of change-- 8288  /Pred-- 4 / Actual-- 6
# Index number of change-- 8292  /Pred-- 7 / Actual-- 5
# Index number of change-- 8293  /Pred-- 4 / Actual-- 6
# Index number of change-- 8312  /Pred-- 2 / Actual-- 4
# Index number of change-- 8317  /Pred-- 3 / Actual-- 0
# Index number of change-- 8324  /Pred-- 3 / Actual-- 0
# Index number of change-- 8338  /Pred-- 9 / Actual-- 7
# Index number of change-- 8341  /Pred-- 6 / Actual-- 3
# Index number of change-- 8348  /Pred-- 6 / Actual-- 0
# Index number of change-- 8373  /Pred-- 2 / Actual-- 6
# Index number of change-- 8374  /Pred-- 2 / Actual-- 6
# Index number of change-- 8399  /Pred-- 4 / Actual-- 6
# Index number of change-- 8417  /Pred-- 6 / Actual-- 2
# Index number of change-- 8436  /Pred-- 4 / Actual-- 2
# Index number of change-- 8457  /Pred-- 6 / Actual-- 4
# Index number of change-- 8459  /Pred-- 0 / Actual-- 6
# Index number of change-- 8462  /Pred-- 6 / Actual-- 4
# Index number of change-- 8463  /Pred-- 7 / Actual-- 5
# Index number of change-- 8476  /Pred-- 2 / Actual-- 4
# Index number of change-- 8487  /Pred-- 7 / Actual-- 9
# Index number of change-- 8505  /Pred-- 9 / Actual-- 7
# Index number of change-- 8509  /Pred-- 4 / Actual-- 2
# Index number of change-- 8519  /Pred-- 2 / Actual-- 6
# Index number of change-- 8525  /Pred-- 7 / Actual-- 9
# Index number of change-- 8532  /Pred-- 7 / Actual-- 5
# Index number of change-- 8536  /Pred-- 2 / Actual-- 4
# Index number of change-- 8537  /Pred-- 2 / Actual-- 6
# Index number of change-- 8538  /Pred-- 0 / Actual-- 6
# Index number of change-- 8540  /Pred-- 4 / Actual-- 2
# Index number of change-- 8548  /Pred-- 2 / Actual-- 4
# Index number of change-- 8556  /Pred-- 3 / Actual-- 4
# Index number of change-- 8568  /Pred-- 6 / Actual-- 8
# Index number of change-- 8569  /Pred-- 6 / Actual-- 4
# Index number of change-- 8580  /Pred-- 2 / Actual-- 4
# Index number of change-- 8593  /Pred-- 6 / Actual-- 2
# Index number of change-- 8598  /Pred-- 0 / Actual-- 2
# Index number of change-- 8607  /Pred-- 7 / Actual-- 9
# Index number of change-- 8610  /Pred-- 0 / Actual-- 1
# Index number of change-- 8617  /Pred-- 3 / Actual-- 6
# Index number of change-- 8618  /Pred-- 6 / Actual-- 2
# Index number of change-- 8622  /Pred-- 0 / Actual-- 6
# Index number of change-- 8624  /Pred-- 4 / Actual-- 2
# Index number of change-- 8633  /Pred-- 8 / Actual-- 6
# Index number of change-- 8645  /Pred-- 6 / Actual-- 0
# Index number of change-- 8646  /Pred-- 4 / Actual-- 3
# Index number of change-- 8649  /Pred-- 6 / Actual-- 0
# Index number of change-- 8658  /Pred-- 0 / Actual-- 6
# Index number of change-- 8664  /Pred-- 0 / Actual-- 6
# Index number of change-- 8669  /Pred-- 0 / Actual-- 2
# Index number of change-- 8670  /Pred-- 6 / Actual-- 0
# Index number of change-- 8678  /Pred-- 6 / Actual-- 4
# Index number of change-- 8693  /Pred-- 2 / Actual-- 4
# Index number of change-- 8695  /Pred-- 6 / Actual-- 0
# Index number of change-- 8704  /Pred-- 7 / Actual-- 9
# Index number of change-- 8706  /Pred-- 2 / Actual-- 6
# Index number of change-- 8708  /Pred-- 4 / Actual-- 3
# Index number of change-- 8710  /Pred-- 4 / Actual-- 2
# Index number of change-- 8713  /Pred-- 9 / Actual-- 7
# Index number of change-- 8714  /Pred-- 5 / Actual-- 7
# Index number of change-- 8717  /Pred-- 6 / Actual-- 0
# Index number of change-- 8723  /Pred-- 6 / Actual-- 4
# Index number of change-- 8745  /Pred-- 0 / Actual-- 6
# Index number of change-- 8748  /Pred-- 0 / Actual-- 6
# Index number of change-- 8754  /Pred-- 9 / Actual-- 7
# Index number of change-- 8757  /Pred-- 0 / Actual-- 1
# Index number of change-- 8758  /Pred-- 4 / Actual-- 2
# Index number of change-- 8762  /Pred-- 2 / Actual-- 6
# Index number of change-- 8763  /Pred-- 8 / Actual-- 0
# Index number of change-- 8764  /Pred-- 2 / Actual-- 3
# Index number of change-- 8768  /Pred-- 6 / Actual-- 1
# Index number of change-- 8772  /Pred-- 9 / Actual-- 5
# Index number of change-- 8774  /Pred-- 6 / Actual-- 2
# Index number of change-- 8782  /Pred-- 6 / Actual-- 0
# Index number of change-- 8784  /Pred-- 4 / Actual-- 6
# Index number of change-- 8787  /Pred-- 2 / Actual-- 6
# Index number of change-- 8799  /Pred-- 6 / Actual-- 4
# Index number of change-- 8804  /Pred-- 2 / Actual-- 4
# Index number of change-- 8806  /Pred-- 0 / Actual-- 3
# Index number of change-- 8827  /Pred-- 3 / Actual-- 4
# Index number of change-- 8832  /Pred-- 2 / Actual-- 0
# Index number of change-- 8845  /Pred-- 6 / Actual-- 4
# Index number of change-- 8865  /Pred-- 9 / Actual-- 7
# Index number of change-- 8877  /Pred-- 0 / Actual-- 2
# Index number of change-- 8888  /Pred-- 6 / Actual-- 8
# Index number of change-- 8896  /Pred-- 0 / Actual-- 3
# Index number of change-- 8906  /Pred-- 0 / Actual-- 6
# Index number of change-- 8914  /Pred-- 6 / Actual-- 2
# Index number of change-- 8918  /Pred-- 4 / Actual-- 6
# Index number of change-- 8919  /Pred-- 2 / Actual-- 0
# Index number of change-- 8923  /Pred-- 0 / Actual-- 6
# Index number of change-- 8933  /Pred-- 2 / Actual-- 4
# Index number of change-- 8946  /Pred-- 4 / Actual-- 6
# Index number of change-- 8950  /Pred-- 6 / Actual-- 2
# Index number of change-- 8952  /Pred-- 7 / Actual-- 9
# Index number of change-- 8958  /Pred-- 2 / Actual-- 4
# Index number of change-- 8969  /Pred-- 2 / Actual-- 4
# Index number of change-- 8971  /Pred-- 7 / Actual-- 9
# Index number of change-- 8972  /Pred-- 9 / Actual-- 7
# Index number of change-- 8997  /Pred-- 0 / Actual-- 6
# Index number of change-- 9004  /Pred-- 2 / Actual-- 6
# Index number of change-- 9017  /Pred-- 3 / Actual-- 0
# Index number of change-- 9023  /Pred-- 6 / Actual-- 4
# Index number of change-- 9025  /Pred-- 2 / Actual-- 6
# Index number of change-- 9032  /Pred-- 2 / Actual-- 6
# Index number of change-- 9033  /Pred-- 4 / Actual-- 6
# Index number of change-- 9055  /Pred-- 6 / Actual-- 8
# Index number of change-- 9059  /Pred-- 0 / Actual-- 3
# Index number of change-- 9067  /Pred-- 6 / Actual-- 2
# Index number of change-- 9069  /Pred-- 2 / Actual-- 6
# Index number of change-- 9074  /Pred-- 6 / Actual-- 0
# Index number of change-- 9094  /Pred-- 2 / Actual-- 6
# Index number of change-- 9095  /Pred-- 0 / Actual-- 1
# Index number of change-- 9122  /Pred-- 0 / Actual-- 6
# Index number of change-- 9128  /Pred-- 2 / Actual-- 6
# Index number of change-- 9131  /Pred-- 2 / Actual-- 6
# Index number of change-- 9133  /Pred-- 0 / Actual-- 6
# Index number of change-- 9138  /Pred-- 4 / Actual-- 2
# Index number of change-- 9140  /Pred-- 0 / Actual-- 6
# Index number of change-- 9143  /Pred-- 6 / Actual-- 4
# Index number of change-- 9148  /Pred-- 2 / Actual-- 6
# Index number of change-- 9152  /Pred-- 9 / Actual-- 7
# Index number of change-- 9160  /Pred-- 2 / Actual-- 4
# Index number of change-- 9161  /Pred-- 0 / Actual-- 6
# Index number of change-- 9165  /Pred-- 0 / Actual-- 3
# Index number of change-- 9171  /Pred-- 4 / Actual-- 2
# Index number of change-- 9180  /Pred-- 0 / Actual-- 6
# Index number of change-- 9183  /Pred-- 8 / Actual-- 6
# Index number of change-- 9199  /Pred-- 3 / Actual-- 6
# Index number of change-- 9211  /Pred-- 0 / Actual-- 6
# Index number of change-- 9218  /Pred-- 2 / Actual-- 6
# Index number of change-- 9222  /Pred-- 0 / Actual-- 6
# Index number of change-- 9227  /Pred-- 0 / Actual-- 6
# Index number of change-- 9237  /Pred-- 2 / Actual-- 0
# Index number of change-- 9238  /Pred-- 5 / Actual-- 7
# Index number of change-- 9247  /Pred-- 4 / Actual-- 6
# Index number of change-- 9251  /Pred-- 4 / Actual-- 0
# Index number of change-- 9256  /Pred-- 4 / Actual-- 2
# Index number of change-- 9260  /Pred-- 4 / Actual-- 3
# Index number of change-- 9261  /Pred-- 0 / Actual-- 6
# Index number of change-- 9263  /Pred-- 6 / Actual-- 4
# Index number of change-- 9276  /Pred-- 6 / Actual-- 2
# Index number of change-- 9291  /Pred-- 6 / Actual-- 0
# Index number of change-- 9297  /Pred-- 3 / Actual-- 6
# Index number of change-- 9298  /Pred-- 8 / Actual-- 0
# Index number of change-- 9306  /Pred-- 2 / Actual-- 6
# Index number of change-- 9308  /Pred-- 6 / Actual-- 2
# Index number of change-- 9324  /Pred-- 7 / Actual-- 5
# Index number of change-- 9325  /Pred-- 2 / Actual-- 3
# Index number of change-- 9329  /Pred-- 6 / Actual-- 2
# Index number of change-- 9342  /Pred-- 6 / Actual-- 0
# Index number of change-- 9344  /Pred-- 2 / Actual-- 4
# Index number of change-- 9349  /Pred-- 4 / Actual-- 0
# Index number of change-- 9350  /Pred-- 0 / Actual-- 6
# Index number of change-- 9351  /Pred-- 0 / Actual-- 6
# Index number of change-- 9358  /Pred-- 7 / Actual-- 9
# Index number of change-- 9364  /Pred-- 2 / Actual-- 6
# Index number of change-- 9379  /Pred-- 4 / Actual-- 3
# Index number of change-- 9397  /Pred-- 4 / Actual-- 2
# Index number of change-- 9398  /Pred-- 6 / Actual-- 0
# Index number of change-- 9402  /Pred-- 0 / Actual-- 6
# Index number of change-- 9405  /Pred-- 6 / Actual-- 0
# Index number of change-- 9438  /Pred-- 6 / Actual-- 0
# Index number of change-- 9441  /Pred-- 4 / Actual-- 2
# Index number of change-- 9443  /Pred-- 6 / Actual-- 2
# Index number of change-- 9445  /Pred-- 4 / Actual-- 6
# Index number of change-- 9446  /Pred-- 6 / Actual-- 0
# Index number of change-- 9449  /Pred-- 6 / Actual-- 2
# Index number of change-- 9450  /Pred-- 6 / Actual-- 1
# Index number of change-- 9465  /Pred-- 4 / Actual-- 2
# Index number of change-- 9475  /Pred-- 6 / Actual-- 2
# Index number of change-- 9484  /Pred-- 2 / Actual-- 6
# Index number of change-- 9485  /Pred-- 2 / Actual-- 1
# Index number of change-- 9487  /Pred-- 3 / Actual-- 6
# Index number of change-- 9499  /Pred-- 3 / Actual-- 6
# Index number of change-- 9513  /Pred-- 4 / Actual-- 6
# Index number of change-- 9517  /Pred-- 2 / Actual-- 4
# Index number of change-- 9524  /Pred-- 7 / Actual-- 8
# Index number of change-- 9529  /Pred-- 3 / Actual-- 6
# Index number of change-- 9537  /Pred-- 4 / Actual-- 2
# Index number of change-- 9538  /Pred-- 6 / Actual-- 0
# Index number of change-- 9539  /Pred-- 2 / Actual-- 4
# Index number of change-- 9545  /Pred-- 4 / Actual-- 2
# Index number of change-- 9548  /Pred-- 2 / Actual-- 1
# Index number of change-- 9551  /Pred-- 9 / Actual-- 7
# Index number of change-- 9571  /Pred-- 6 / Actual-- 0
# Index number of change-- 9573  /Pred-- 3 / Actual-- 6
# Index number of change-- 9574  /Pred-- 6 / Actual-- 2
# Index number of change-- 9577  /Pred-- 2 / Actual-- 0
# Index number of change-- 9580  /Pred-- 0 / Actual-- 6
# Index number of change-- 9582  /Pred-- 6 / Actual-- 2
# Index number of change-- 9588  /Pred-- 0 / Actual-- 3
# Index number of change-- 9590  /Pred-- 6 / Actual-- 8
# Index number of change-- 9601  /Pred-- 0 / Actual-- 6
# Index number of change-- 9602  /Pred-- 0 / Actual-- 6
# Index number of change-- 9614  /Pred-- 7 / Actual-- 9
# Index number of change-- 9622  /Pred-- 0 / Actual-- 3
# Index number of change-- 9623  /Pred-- 2 / Actual-- 1
# Index number of change-- 9632  /Pred-- 2 / Actual-- 4
# Index number of change-- 9639  /Pred-- 4 / Actual-- 2
# Index number of change-- 9647  /Pred-- 2 / Actual-- 1
# Index number of change-- 9662  /Pred-- 6 / Actual-- 0
# Index number of change-- 9663  /Pred-- 0 / Actual-- 6
# Index number of change-- 9666  /Pred-- 3 / Actual-- 1
# Index number of change-- 9674  /Pred-- 5 / Actual-- 9
# Index number of change-- 9675  /Pred-- 4 / Actual-- 3
# Index number of change-- 9679  /Pred-- 6 / Actual-- 4
# Index number of change-- 9684  /Pred-- 4 / Actual-- 6
# Index number of change-- 9690  /Pred-- 2 / Actual-- 6
# Index number of change-- 9692  /Pred-- 3 / Actual-- 6
# Index number of change-- 9705  /Pred-- 7 / Actual-- 9
# Index number of change-- 9706  /Pred-- 4 / Actual-- 2
# Index number of change-- 9714  /Pred-- 0 / Actual-- 6
# Index number of change-- 9719  /Pred-- 3 / Actual-- 0
# Index number of change-- 9729  /Pred-- 0 / Actual-- 6
# Index number of change-- 9743  /Pred-- 4 / Actual-- 2
# Index number of change-- 9748  /Pred-- 6 / Actual-- 0
# Index number of change-- 9791  /Pred-- 8 / Actual-- 0
# Index number of change-- 9809  /Pred-- 3 / Actual-- 0
# Index number of change-- 9831  /Pred-- 0 / Actual-- 6
# Index number of change-- 9835  /Pred-- 7 / Actual-- 9
# Index number of change-- 9856  /Pred-- 6 / Actual-- 8
# Index number of change-- 9868  /Pred-- 2 / Actual-- 6
# Index number of change-- 9879  /Pred-- 5 / Actual-- 7
# Index number of change-- 9880  /Pred-- 1 / Actual-- 0
# Index number of change-- 9884  /Pred-- 6 / Actual-- 0
# Index number of change-- 9887  /Pred-- 0 / Actual-- 6
# Index number of change-- 9891  /Pred-- 6 / Actual-- 1
# Index number of change-- 9904  /Pred-- 4 / Actual-- 6
# Index number of change-- 9916  /Pred-- 6 / Actual-- 1
# Index number of change-- 9917  /Pred-- 9 / Actual-- 7
# Index number of change-- 9928  /Pred-- 8 / Actual-- 0
# Index number of change-- 9933  /Pred-- 2 / Actual-- 4
# Index number of change-- 9946  /Pred-- 8 / Actual-- 2
# Index number of change-- 9947  /Pred-- 2 / Actual-- 6
# Index number of change-- 9949  /Pred-- 7 / Actual-- 5
# Index number of change-- 9953  /Pred-- 2 / Actual-- 6
# Index number of change-- 9955  /Pred-- 0 / Actual-- 6
# Index number of change-- 9957  /Pred-- 0 / Actual-- 6
# Index number of change-- 9961  /Pred-- 2 / Actual-- 6
# Index number of change-- 9963  /Pred-- 2 / Actual-- 4
# Index number of change-- 9969  /Pred-- 4 / Actual-- 8
# Index number of change-- 9972  /Pred-- 6 / Actual-- 2
# Index number of change-- 9977  /Pred-- 0 / Actual-- 6
# Index number of change-- 9979  /Pred-- 0 / Actual-- 6
# Index number of change-- 9989  /Pred-- 2 / Actual-- 4
# Index number of change-- 9999  /Pred-- 7 / Actual-- 5

# %%
image = X_test[12,:].reshape((28,28))
plt.imshow(image)

# %% [markdown]
# # Standard Scaller

# %%
X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %%
start = time.time()
rfc.fit(X_train, y_train)
end = time.time()
print('Time spent after scaling with scallar --', end-start)
predict = rfc.predict(X_test)
# Out:
# Time spent after scaling with scallar -- 24.106032609939575

# %%
rfc.score(X_train,y_train)
print ("Train Standard Scallar --", rfc.score(X_train,y_train))
rfc.score(X_test,y_test)
print ("Test Standard Scallar --", rfc.score(X_test,y_test))
# Out:
# Train Standard Scallar -- 0.9949666666666667
# Test Standard Scallar -- 0.8504

# %%
acc = metrics.accuracy_score(predict,y_test)
print("Test accuracy_score --",acc)
# Out:
# Test accuracy_score -- 0.8504

# %% [markdown]
# # 3 + 4) Pca Scaller and test time

# %%
from sklearn.decomposition import PCA
pca = PCA(.95)
pca.fit(X_train)
pca_train = pca.transform(X_train)
pca_test = pca.transform(X_test)

# %%
start = time.time()
rfc.fit(pca_train, y_train)
end = time.time()
PCA_timer = end-start
print('Time spent after PCA scaling --',end-start)
start = time.time()
predict = rfc.predict(pca_test)
end = time.time()
print('Time spent after Prediction PCA  --',end-start)
# Out:
# Time spent after PCA scaling -- 26.17758321762085
# Time spent after Prediction PCA  -- 0.07157135009765625

# %%
rfc.score(pca_train,y_train)
print ("Train PCA Scallar --", rfc.score(pca_train,y_train))
PCA_testresult = rfc.score(pca_test,y_test)
print ("Test PCA Scallar --", rfc.score(pca_test,y_test))
# Out:
# Train PCA Scallar -- 0.9956666666666667
# Test PCA Scallar -- 0.8117

# %%
acc = metrics.accuracy_score(predict,y_test)
print("Test accuracy_score --",acc)
# Out:
# Test accuracy_score -- 0.8117

# %% [markdown]
# # 5 + 6) Compare resultsing PCA/RFC

# %%
print('Score Rfc - ',test_resultrfc,'/Timer Rfc - ',rfc_timer)
print('Score PCA - ',PCA_testresult, '/Timer PCA - ',PCA_timer)
# Out:
# Score Rfc -  0.855 /Timer Rfc -  18.87619376182556
# Score PCA -  0.8117 /Timer PCA -  26.17758321762085

# %% [markdown]
# The PCA accuracy score came out lower and slower than the RFC score

# %% [markdown]
# # 7 + 8) Softmax

# %%
start = time.time()
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(X_train, y_train)
end = time.time()
predi = clf.predict_proba(X_test2) 
print('Softmax normal --', end-start)
CLF_timer = end-start
# Out:
# Softmax normal -- 19.408984661102295
# C:\Users\Max\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
CLF_result = clf.score(X_test2,y_test2)

# %%
start = time.time()
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(pca_train, y_train)
end = time.time()
pred = clf.predict_proba(pca_test) 
print('Softmax PCA --', end-start)
PCA_timer = end-start
# Out:
# Softmax PCA -- 10.453884840011597
# C:\Users\Max\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
CLFpca_testresult = clf.score(pca_test,y_test)

# %%
print('Score CLF - ',CLF_result,'/Timer Rfc - ',CLF_timer)
print('Score PCA - ',CLFpca_testresult, '/Timer PCA - ',PCA_timer)
# Out:
# Score CLF -  0.7419 /Timer Rfc -  19.408984661102295
# Score PCA -  0.8445 /Timer PCA -  10.453884840011597

# %% [markdown]
# # 9) Conclusion?
# PCA is more effective than softmax, is quicker and has a better accuracy.

# %% [markdown]
# # Part 2 Viz
# # 1-3

# %%
from sklearn.manifold import TSNE
RS = 123

x_subset = X_train[0:12500]
y_subset = y_train[0:12500]

# %%
start = time.time()
fashion_tsne = TSNE(n_components=2).fit_transform(x_subset)
end = time.time()
print("Time taken for t-sne", end-start)
# Out:
# Time taken for t-sne 803.5309245586395

# %%
len(fashion_tsne[0,:])
# Out:
# 2

# %%
plt.scatter(fashion_tsne[:,0],fashion_tsne[:,1], c=y_subset,s=0.2)

# %% [markdown]
# Conclusion, items with the same labels are near each other.

# %% [markdown]
# # 4

# %%
df = pd.DataFrame(fashion_tsne,y_subset)

# %%
df = df.loc[[7,9,2]]

# %%
plt.scatter(df[0],df[1], c=df.index,s=2)

# %% [markdown]
# ### Adding labels

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

from yellowbrick.text import TSNEVisualizer

# Create the visualizer and draw the vectors
tsne = TSNEVisualizer()
tsne.fit(x_subset, y_subset)
tsne.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
